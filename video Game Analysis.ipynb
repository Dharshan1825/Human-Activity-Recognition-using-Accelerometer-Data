# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharshan1825/Human-Activity-Recognition-using-Accelerometer-Data/blob/main/video%20Game%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

games = pd.read_csv("games.csv")
sales = pd.read_csv("vgsales.csv")

print("Games Head:")
display(games.head())

print("\nSales Head:")
display(sales.head())

print("\nShapes:")
print(games.shape)
print(sales.shape)
# Out:
# (1512, 14)
# (16598, 11)
